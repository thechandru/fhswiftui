# %%
#| default_exp core

# %% [markdown]
# # fhswiftui.core
#
# > API for helpers, layout components, UI components, and style modifiers.

# %%
#| export
from fastcore.utils import *
from fasthtml.common import *
import fasthtml.components as fh
from fasthtml.jupyter import *

# %% [markdown]
# ## Basics

# %%
#| export
#| hide
def _def_colors():
    base = ["primary","secondary","accent","muted","card","popover"]
    return base+[f"{o}-foreground" for o in base]+["background","foreground","destructive","ring","input","border"]

# %%
#| export
def IncludeColors(
    colors=None,    # list of tailwind colors
    append=True     # append or replace the default colors
):
    "Include additional colors that wil be used in the page"
    from itertools import product
    if not colors: colors = []
    pr = [f"border-{o}" for o in "lrtb"] + ["bg","text","border"]
    
    return Div(cls=f"hidden {' '.join(f'{p}-{c}' for p,c in product(pr,_def_colors() + colors if append else colors))}")

# %%
#| export
# enable basecoat and tailwind; add useful default colors
bc_link = Link(rel='stylesheet', href='https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css')
tw_scr = Script(src='https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4')

fh_swiftui_hdrs = (bc_link,tw_scr,IncludeColors())

# %%
fh_swiftui_hdrs
# Out:
# (link((),{'rel': 'stylesheet', 'href': 'https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css'}),
#  script(('',),{'src': 'https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4'}),
#  div((),{'class': 'hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border'}))

# %%
#| export
def mk_previewer(app=None,hdrs=fh_swiftui_hdrs,cls=f'max-w-lg'):
    xcls = cls
    if not app: app=FastHTML(hdrs=hdrs)
    def p(*c, cls='', **kw):
        return HTMX(Div(cls=f'{xcls} {cls}')(*c), app=app, host=None, port=None, **kw)
    return p

# Based completely on: https://answerdotai.github.io/fhdaisy/core.html#mk_previewer

# %%
#| export
p = mk_previewer()

# %%
c = Button("hello", cls="btn")
p(c)
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_k_eiFINjTk26J4CV3WgfqQ&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
# &lt;button class=&quot;btn&quot;&gt;hello&lt;/button&gt;     &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
c
# Out:
# button(('hello',),{'class': 'btn'})

# %% [markdown]
# ## Style modifiers

# %%
#| export
@patch
def append_classes(
    self:FT, # the tag
    *c       # list of classes
):
    "Append css classes to the FastTag element"
    self.attrs["class"] = " ".join(f"{self.attrs.get('class','')} {' '.join(c)}".split())
    return self

# %% [markdown]
# ### Padding - space inside the component

# %%
#| export
@patch
def padding(
    self:FT,     # The FastTag element to modify
    **kw         # Padding values: 'all', 'top', 'bottom', 'left', 'right' (Tailwind spacing scale: 0, 1, 2, 4, 8, px, or custom like '[5px]')
):
    "Add padding around the content within the element's bounds. Defaults to p-4 if no arguments provided."
    d = {"top":'t', "bottom":'b', "left":'l', "right":'r'}
    c = [f"p-{kw['all']}"] if "all" in kw else [f"p{d[k]}-{kw[k]}" for k in set(kw) & d.keys()]
    return self.append_classes(*c if c else ["p-4"])

# %% [markdown]
# #### Tests

# %%
#| export
# Test with different padding options
Div("Default", cls="bg-blue-200").padding()
# Out:
# div(('Default',),{'class': 'bg-blue-200 p-4'})

# %%
#| export
# Test with different padding options
p(Div("Default", cls="bg-blue-200").padding())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_dXS3NoXjTzS0qGAGzN2F5g&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-blue-200 p-4&quot;&gt;Default&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
Div("All sides", cls="bg-blue-200").padding(all=6)
# Out:
# div(('All sides',),{'class': 'bg-blue-200 p-6'})

# %%
#| export
p(Div("All sides", cls="bg-blue-200").padding(all=6))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_yGp_CIfKReal6SXnc9-xsQ&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-blue-200 p-6&quot;&gt;All sides&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
Div("Top and bottom", cls="bg-blue-200").padding(top=2, bottom=8)
# Out:
# div(('Top and bottom',),{'class': 'bg-blue-200 pb-8 pt-2'})

# %%
#| export
p(Div("Top and bottom", cls="bg-blue-200").padding(top=2, bottom=8))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_8PcECx6PRPOSCLMtt8WdWg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-blue-200 pb-8 pt-2&quot;&gt;Top and bottom&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# ### Margins - space outside the component

# %%
#| export
@patch
def margin(self:FT,**kw):
    d = {"top":'t',"bottom":'b',"left":'l',"right":'r'}
    c = [f"m-{kw['all']}"] if "all" in kw else [f"m{d[k]}-{kw[k]}" for k in set(kw) & d.keys()]

    self.append_classes(*c if c else ["m-4"])

    return self

# %% [markdown]
# #### Tests

# %%
#| export
# Default margin
p(Div("Default", cls="bg-blue-200").margin())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_kHaN5O9FQ16ysRs0v_NlTg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-blue-200 m-4&quot;&gt;Default&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# All sides
p(Div("All sides", cls="bg-blue-200").margin(all=6))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_hNMB1huoSVuY7shJM5kS3Q&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-blue-200 m-6&quot;&gt;All sides&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# Top and bottom
p(Div("Top and bottom", cls="bg-blue-200").margin(top=2, bottom=8))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_rNc1LqlZQ4qmGzI9YIrHPQ&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-blue-200 mb-8 mt-2&quot;&gt;Top and bottom&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# ### Borders

# %%
#| export
@patch
def border(
    self:FT,         # The FastTag element to modify
    width:int=None,  # Border width in Tailwind scale (1, 2, 4, 8) or None for default width
    color:str=None   # Tailwind border color without 'border-' prefix (e.g., 'primary', 'muted', 'gray-300', 'red-500')
):
    "Add a border around the element with optional width and color customization"
    c = ["border"]
    if width: c.append(f"border-{width}")
    if color: c.append(f"border-{color}")
    return self.append_classes(*c)

# %% [markdown]
# #### Tests

# %%
#| export
p(Div("Test").border())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_nnlDQvAeR8y6LqUGFs6Mrg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;border&quot;&gt;Test&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Test").border(width=2,color="blue-500"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_Nbe8e5XUSlOD_1v1ISnPTg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;border border-2 border-blue-500&quot;&gt;Test&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Test").border(color="red-300"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_-tL9xtvSShWFNwI8d1wX9g&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;border border-red-300&quot;&gt;Test&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Test").border().padding().margin())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_H-icVt3dRxCGHnKtUufOiQ&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;border p-4 m-4&quot;&gt;Test&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# #| export
# ### Corner radius

# %%
#| export
@patch
def corner_radius(
    self:FT,        # The FastTag element to modify
    sz:str=None     # Tailwind size suffix
):   
    "Round the corners for this element"
    return self.append_classes(f"rounded-{sz}" if sz else "rounded")

# %% [markdown]
# #### Tests

# %%
#| export
# Default rounded
p(Div("Default", cls="bg-blue-200 p-4").corner_radius())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_rP7rBD6CRAyOh3cVPv4cHQ&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-blue-200 p-4 rounded&quot;&gt;Default&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# Specific sizes
p(Div("Small", cls="bg-green-200 p-4").corner_radius("sm"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_uJnNwYuCRmeZRIVzQuLHuQ&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-green-200 p-4 rounded-sm&quot;&gt;Small&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Large", cls="bg-red-200 p-4").corner_radius("lg"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_ugDeDAGyQaiZVOov9KPe0Q&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-red-200 p-4 rounded-lg&quot;&gt;Large&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Full", cls="bg-yellow-200 p-4").corner_radius("full"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_sUjLttXtS3en6e6aKeoPfw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-yellow-200 p-4 rounded-full&quot;&gt;Full&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Chaining").padding().border().corner_radius("lg"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_1dmX5_sKQICTA_RkhGnONg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;p-4 border rounded-lg&quot;&gt;Chaining&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# ### bg/fg - set background and foreground colors

# %%
#| export
@patch
def bg(
    self:FT,        # The FastTag element to modify
    color:str       # color of background
): 
    "Set background color"
    return self.append_classes(f"bg-{color}")

# %%
#| export
@patch
def fg(
    self:FT,        # The FastTag element to modify
    color:str       # color of foreground
): 
    "Set foreground color"
    return self.append_classes(f"text-{color}")

# %% [markdown]
# #### Tests

# %%
#| export
# Background color
p(Div("Blue background").padding().bg("blue-500"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_eaFE-EhPQbK4DGKz_Oi29A&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;p-4 bg-blue-500&quot;&gt;Blue background&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# Foreground/text color
p(Div("Red text").padding().fg("red-600"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_dQrQvfrjSfaA5YbvU6m7jg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;p-4 text-red-600&quot;&gt;Red text&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# Combined
p(Div("Yellow on purple", cls="p-4").bg("purple-700").fg("yellow-300"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_2REFI4nTT-yXOFIFfAHsIg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;p-4 bg-purple-700 text-yellow-300&quot;&gt;Yellow on purple&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# With other modifiers
p(Div("Styled box", cls="p-4").bg("green-200").fg("green-900").corner_radius("lg").border(width=2, color="green-500"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/__FsoYK7jSj_ky2azoJ-F5g&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;p-4 bg-green-200 text-green-900 rounded-lg border border-2 border-green-500&quot;&gt;Styled box&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# ### shadow - set shadow

# %%
#| export
@patch
def shadow(self:FT,**kw):
    "Add shadow to element"
    # Parameters:
    # c: shadow color (default 'rgba(0,0,0,0.1)')
    # sz: preset size ('sm','md','lg', etc)
    # x,y,b,s: offset x, offset y, blur, spread
    if "c" not in kw: kw["c"] = "rgba(0,0,0,0.1)"
    
    if len(kw) == 0: return self.append_classes("shadow")
    if "sz" in kw: return self.append_classes(f"shadow-{kw['sz']}")
    
    def enc(c,x=0,y=1,b=3,s=0,**k2): return f"shadow-[{x}px_{y}px_{b}px_{s}px_{c}]"
    return self.append_classes(enc(**kw))

# %% [markdown]
# #### Tests

# %%
#| export
# Default shadow
p(Button("Default Shadow", cls="btn btn-primary").shadow())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_4KVqMwfEQheeEbbNQHVWkQ&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
# &lt;button class=&quot;btn btn-primary shadow-[0px_1px_3px_0px_rgba(0,0,0,0.1)]&quot;&gt;Default Shadow&lt;/button&gt;     &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# Custom color shadow
p(Button("Blue Shadow", cls="btn").shadow(c="rgba(0,0,255,0.5)", x=2, y=2, blur=8))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_bD3s3Q4GR-aQk1ifmtOkRg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
# &lt;button class=&quot;btn shadow-[2px_2px_3px_0px_rgba(0,0,255,0.5)]&quot;&gt;Blue Shadow&lt;/button&gt;     &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# Large offset shadow
p(Button("Offset Shadow", cls="btn btn-secondary").shadow(x=4, y=8, b=12))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_ngfDLTN-RtmgKUjc8exorw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
# &lt;button class=&quot;btn btn-secondary shadow-[4px_8px_12px_0px_rgba(0,0,0,0.1)]&quot;&gt;Offset Shadow&lt;/button&gt;     &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# Red shadow
p(Button("Red Shadow", cls="btn btn-accent").shadow(color="red", blur=10))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_ZljopihJTReH6MPb2Cz8Lw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
# &lt;button class=&quot;btn btn-accent shadow-[0px_1px_3px_0px_rgba(0,0,0,0.1)]&quot;&gt;Red Shadow&lt;/button&gt;     &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# ### opacity - set opacity

# %%
#| export
@patch
def opacity(
    self:FT,        # The FastTag element to modify
    v:int=100       # Percent value of opacity as int
):
    "set opacity"
    return self.append_classes(f"opacity-{v}")

# %% [markdown]
# #### Tests

# %%
#| export
p(Div("Full opacity (default)", cls="bg-blue-500 p-4 text-white").opacity())
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_ktsQVwS6SD2Nl5LFxhoG7w&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-blue-500 p-4 text-white opacity-100&quot;&gt;Full opacity (default)&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("75% opacity", cls="bg-red-500 p-4 text-white").opacity(75))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_xSZ94V4RTzGCc3JQrVYIIw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-red-500 p-4 text-white opacity-75&quot;&gt;75% opacity&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("50% opacity", cls="bg-green-500 p-4 text-white").opacity(50))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_h8nMKepxQ1qVuz_UCCZRJA&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-green-500 p-4 text-white opacity-50&quot;&gt;50% opacity&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("25% opacity", cls="bg-purple-500 p-4 text-white").opacity(25))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_9nXfnnpESH_8k0JHlLTkvw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;bg-purple-500 p-4 text-white opacity-25&quot;&gt;25% opacity&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div(
    Div("100", cls="bg-blue-500 p-4 text-white").opacity(100),
    Div("75", cls="bg-blue-500 p-4 text-white").opacity(75),
    Div("50", cls="bg-blue-500 p-4 text-white").opacity(50),
    Div("25", cls="bg-blue-500 p-4 text-white").opacity(25)
))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_znq2mXI5RNm2W36YSApTQw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div&gt;
#          &lt;div class=&quot;bg-blue-500 p-4 text-white opacity-100&quot;&gt;100&lt;/div&gt;
#          &lt;div class=&quot;bg-blue-500 p-4 text-white opacity-75&quot;&gt;75&lt;/div&gt;
#          &lt;div class=&quot;bg-blue-500 p-4 text-white opacity-50&quot;&gt;50&lt;/div&gt;
#          &lt;div class=&quot;bg-blue-500 p-4 text-white opacity-25&quot;&gt;25&lt;/div&gt;
#        &lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# ### frame - position this within a frame

# %%
#| export
@patch
def frame(
    self:FT,            # The FastTag element to modify 
    w=None,             # height of frame
    h=None,             # width of frame
    halign="center",    # horizontal alignment (default: center)
    valign="center"     # vertical alignment (default: center)
):
    "position this element in a frame"
    h_map = {"leading": "justify-start", "center": "justify-center", "trailing": "justify-end"}
    v_map = {"top": "items-start", "center": "items-center", "bottom": "items-end"}
    
    c = ["flex", h_map[halign], v_map[valign]]
    if w: c.append(f"w-{w}")
    if h: c.append(f"h-{h}")
    
    return Div(self).append_classes(*c)

# %% [markdown]
# #| export
# #### Tests

# %%
#| export
# Basic frame with size
p(Div("Content", cls="bg-blue-200 p-2").frame(w=64, h=32))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_RaAibwIQTzq9gEzizZxJOw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;flex justify-center items-center w-64 h-32&quot;&gt;
#          &lt;div class=&quot;bg-blue-200 p-2&quot;&gt;Content&lt;/div&gt;
#        &lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# Different alignments
p(Div("Top Left", cls="bg-red-200 p-2").frame(w=96, h=48, valign="top",halign="leading"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_ciBWLFrsQXyJqBsdJVfyVg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;flex justify-start items-start w-96 h-48&quot;&gt;
#          &lt;div class=&quot;bg-red-200 p-2&quot;&gt;Top Left&lt;/div&gt;
#        &lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Center", cls="bg-green-200 p-2").frame(w=96, h=48, halign="center"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_CoTfeQseQMWkNr20CnOrHQ&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;flex justify-center items-center w-96 h-48&quot;&gt;
#          &lt;div class=&quot;bg-green-200 p-2&quot;&gt;Center&lt;/div&gt;
#        &lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Bottom Right", cls="bg-yellow-200 p-2").frame(w=96, h=48, valign="bottom",halign="trailing"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_Ge7jpEckQHCjK9eUzm2aLA&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;flex justify-end items-end w-96 h-48&quot;&gt;
#          &lt;div class=&quot;bg-yellow-200 p-2&quot;&gt;Bottom Right&lt;/div&gt;
#        &lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# Just width or height
p(Div("Wide", cls="bg-purple-200 p-2").frame(w="full"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_F0JtI3AvTtKwmwHYwWDtHw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;flex justify-center items-center w-full&quot;&gt;
#          &lt;div class=&quot;bg-purple-200 p-2&quot;&gt;Wide&lt;/div&gt;
#        &lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Tall", cls="bg-pink-200 p-2").frame(h=64))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_kkgTFM5gQkaIeWdEDnZ0Rg&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;flex justify-center items-center h-64&quot;&gt;
#          &lt;div class=&quot;bg-pink-200 p-2&quot;&gt;Tall&lt;/div&gt;
#        &lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %% [markdown]
# ### font - set the default font for the tag

# %%
#| export
@patch
def font(
    self:FT,        # The FastTag element to modify 
    sz=None,        # size
    wt=None         # weight
):
    "Set default font for this tag"
    c = []
    if sz: c.append(f"text-{sz}")
    if wt: c.append(f"font-{wt}")
    return self.append_classes(*c)

# %% [markdown]
# #### Tests

# %%
#| export
# Different font sizes
p(Div("Small text").font(sz="sm"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_aP7kcYlYRkKE600AtMp3oA&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;text-sm&quot;&gt;Small text&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Base text").font(sz="base"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_pj-zXCR_SVWM90C9xXYyqw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;text-base&quot;&gt;Base text&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Large text").font(sz="lg"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_7KYzTOjQQDmiaMbe63u37Q&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;text-lg&quot;&gt;Large text&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Extra large text").font(sz="xl"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_Dl5zZjILQAe3fa9s2ca92w&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;text-xl&quot;&gt;Extra large text&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("2XL text").font(sz="2xl"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_GMNPJni7QhiTGdEg38vL4g&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;text-2xl&quot;&gt;2XL text&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# Different font weights
p(Div("Light text").font(wt="light"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_3c8Nx7R3QlyFF2rcX2zdKQ&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;font-light&quot;&gt;Light text&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Normal text").font(wt="normal"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_dRGAYszGSkWsPv8Whx-tIw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;font-normal&quot;&gt;Normal text&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Bold text").font(wt="bold"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_VAGKpBAXQ3OQwyIQnx80rw&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;font-bold&quot;&gt;Bold text&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
# Combined size and weight
p(Div("Large and bold").font(sz="2xl",wt="bold"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/__VAV0aeCQqSJn171d5gZ6g&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;text-2xl font-bold&quot;&gt;Large and bold&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>

# %%
#| export
p(Div("Small and light").font(sz="sm",wt="light"))
# Out:
# <iframe srcdoc=" &lt;!doctype html&gt;
#  &lt;html&gt;
#    &lt;head&gt;
#      &lt;title&gt;FastHTML page&lt;/title&gt;
#      &lt;link rel=&quot;canonical&quot; href=&quot;https://testserver/_s87DgmQaRk2xqG25ijKP_Q&quot;&gt;
#      &lt;meta charset=&quot;utf-8&quot;&gt;
#      &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, viewport-fit=cover&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/htmx.org@2.0.7/dist/htmx.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/fasthtml-js@1.0.12/fasthtml.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/answerdotai/surreal@main/surreal.js&quot;&gt;&lt;/script&gt;&lt;script src=&quot;https://cdn.jsdelivr.net/gh/gnat/css-scope-inline@main/script.js&quot;&gt;&lt;/script&gt;     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/basecoat-css@latest/dist/basecoat.cdn.min.css&quot;&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4&quot;&gt;&lt;/script&gt;     &lt;div class=&quot;hidden border-l-primary border-l-secondary border-l-accent border-l-muted border-l-card border-l-popover border-l-primary-foreground border-l-secondary-foreground border-l-accent-foreground border-l-muted-foreground border-l-card-foreground border-l-popover-foreground border-l-background border-l-foreground border-l-destructive border-l-ring border-l-input border-l-border border-r-primary border-r-secondary border-r-accent border-r-muted border-r-card border-r-popover border-r-primary-foreground border-r-secondary-foreground border-r-accent-foreground border-r-muted-foreground border-r-card-foreground border-r-popover-foreground border-r-background border-r-foreground border-r-destructive border-r-ring border-r-input border-r-border border-t-primary border-t-secondary border-t-accent border-t-muted border-t-card border-t-popover border-t-primary-foreground border-t-secondary-foreground border-t-accent-foreground border-t-muted-foreground border-t-card-foreground border-t-popover-foreground border-t-background border-t-foreground border-t-destructive border-t-ring border-t-input border-t-border border-b-primary border-b-secondary border-b-accent border-b-muted border-b-card border-b-popover border-b-primary-foreground border-b-secondary-foreground border-b-accent-foreground border-b-muted-foreground border-b-card-foreground border-b-popover-foreground border-b-background border-b-foreground border-b-destructive border-b-ring border-b-input border-b-border bg-primary bg-secondary bg-accent bg-muted bg-card bg-popover bg-primary-foreground bg-secondary-foreground bg-accent-foreground bg-muted-foreground bg-card-foreground bg-popover-foreground bg-background bg-foreground bg-destructive bg-ring bg-input bg-border text-primary text-secondary text-accent text-muted text-card text-popover text-primary-foreground text-secondary-foreground text-accent-foreground text-muted-foreground text-card-foreground text-popover-foreground text-background text-foreground text-destructive text-ring text-input text-border border-primary border-secondary border-accent border-muted border-card border-popover border-primary-foreground border-secondary-foreground border-accent-foreground border-muted-foreground border-card-foreground border-popover-foreground border-background border-foreground border-destructive border-ring border-input border-border&quot;&gt;&lt;/div&gt;
# &lt;script&gt;
#     function sendmsg() {
#         window.parent.postMessage({height: document.documentElement.offsetHeight}, &#x27;*&#x27;);
#     }
#     window.onload = function() {
#         sendmsg();
#         document.body.addEventListener(&#x27;htmx:afterSettle&#x27;,    sendmsg);
#         document.body.addEventListener(&#x27;htmx:wsAfterMessage&#x27;, sendmsg);
#     };&lt;/script&gt;   &lt;/head&gt;
#    &lt;body&gt;
#      &lt;div class=&quot;max-w-lg &quot;&gt;
#        &lt;div class=&quot;text-sm font-light&quot;&gt;Small and light&lt;/div&gt;
#      &lt;/div&gt;
#    &lt;/body&gt;
#  &lt;/html&gt;
# " style="width: 100%; height: auto; border: none;" onload="{
#         let frame = this;
#         window.addEventListener('message', function(e) {
#             if (e.source !== frame.contentWindow) return; // Only proceed if the message is from this iframe
#             if (e.data.height) frame.style.height = (e.data.height+1) + 'px';
#         }, false);
#     }" allow="accelerometer; autoplay; camera; clipboard-read; clipboard-write; display-capture; encrypted-media; fullscreen; gamepad; geolocation; gyroscope; hid; identity-credentials-get; idle-detection; magnetometer; microphone; midi; payment; picture-in-picture; publickey-credentials-get; screen-wake-lock; serial; usb; web-share; xr-spatial-tracking"></iframe>
